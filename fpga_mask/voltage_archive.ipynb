# %%
import numpy as np
from ctypes import *
import time

# %%
NBUF = 5
BLK_SIZE = 1024*400*1000
DATA_SIZE = BLK_SIZE * NBUF
ARCH_BLKS = 60

voltage = np.memmap('/dev/hugepages/voltage.bin', dtype='byte', shape=(DATA_SIZE))
blk_ptr = cast(c_void_p(voltage.ctypes.data + DATA_SIZE), POINTER(c_long))

# %%
last_blk = blk_ptr.contents.value
filename = None
nblk = 0

while True:
    while last_blk == blk_ptr.contents.value:
        time.sleep(0.01)

    data = voltage[BLK_SIZE*last_blk:BLK_SIZE*(last_blk+1)]
    # write data to disk
    if filename is None:
        filename = f'/sdisk1/VoltageData/Voltage_{int(time.time())}'
        fp = open(filename, 'wb')
#    data.tofile(fp)
    fp.write(data.tobytes())

    last_blk = (last_blk + 1) % NBUF
    nblk += 1
    print(f'Block #{last_blk} written, count: {nblk}')
    if nblk >= ARCH_BLKS:
        nblk = 0
        fp.close()
        filename = None
# Out:
# Block #1 written, count: 1
# Block #2 written, count: 2
# Block #3 written, count: 3
# Block #4 written, count: 4
# Block #0 written, count: 5
# Block #1 written, count: 6
# Block #2 written, count: 7
# Block #3 written, count: 8
# Block #4 written, count: 9
# Block #0 written, count: 10
# Block #1 written, count: 11
# Block #2 written, count: 12
# Block #3 written, count: 13
# Block #4 written, count: 14
# Block #0 written, count: 15
# Block #1 written, count: 16
# Block #2 written, count: 17
# Block #3 written, count: 18
# Block #4 written, count: 19
# Block #0 written, count: 20
# Block #1 written, count: 21
# Block #2 written, count: 22
# Block #3 written, count: 23
# Block #4 written, count: 24
# Block #0 written, count: 25
# Block #1 written, count: 26
# Block #2 written, count: 27
# Block #3 written, count: 28
# Block #4 written, count: 29
# Block #0 written, count: 30
# Block #1 written, count: 31
# Block #2 written, count: 32
# Block #3 written, count: 33
# Block #4 written, count: 34
# Block #0 written, count: 35
# Block #1 written, count: 36
# Block #2 written, count: 37
# Block #3 written, count: 38
# Block #4 written, count: 39
# Block #0 written, count: 40
# Block #1 written, count: 41
# Block #2 written, count: 42
# Block #3 written, count: 43
# Block #4 written, count: 44
# Block #0 written, count: 45
# Block #1 written, count: 46
# Block #2 written, count: 47
# Block #3 written, count: 48
# Block #4 written, count: 49
# Block #0 written, count: 50
# Block #1 written, count: 51
# Block #2 written, count: 52
# Block #3 written, count: 53
# Block #4 written, count: 54
# Block #0 written, count: 55
# Block #1 written, count: 56
# Block #2 written, count: 57
# Block #3 written, count: 58
# Block #4 written, count: 59
# Block #0 written, count: 60
# Block #1 written, count: 1
# Block #2 written, count: 2
# Block #3 written, count: 3
# Block #4 written, count: 4
# Block #0 written, count: 5
# Block #1 written, count: 6
# Block #2 written, count: 7
# Block #3 written, count: 8
# Block #4 written, count: 9
# Block #0 written, count: 10
# Block #1 written, count: 11
# Block #2 written, count: 12
# Block #3 written, count: 13
# Block #4 written, count: 14
# Block #0 written, count: 15
# Block #1 written, count: 16
# Block #2 written, count: 17
# Block #3 written, count: 18
# Block #4 written, count: 19
# Block #0 written, count: 20
# Block #1 written, count: 21
# Block #2 written, count: 22
# Block #3 written, count: 23
# Block #4 written, count: 24
# Block #0 written, count: 25
# Block #1 written, count: 26
# Block #2 written, count: 27
# Block #3 written, count: 28
# Block #4 written, count: 29
# Block #0 written, count: 30
# Block #1 written, count: 31
# Block #2 written, count: 32
# Block #3 written, count: 33
# Block #4 written, count: 34
# Block #0 written, count: 35
# Block #1 written, count: 36
# Block #2 written, count: 37
# Block #3 written, count: 38
# Block #4 written, count: 39
# Block #0 written, count: 40
# Block #1 written, count: 41
# Block #2 written, count: 42
# Block #3 written, count: 43
# Block #4 written, count: 44
# Block #0 written, count: 45
# Block #1 written, count: 46
# Block #2 written, count: 47
# Block #3 written, count: 48
# Block #4 written, count: 49
# Block #0 written, count: 50
# Block #1 written, count: 51
# Block #2 written, count: 52
# Block #3 written, count: 53
# Block #4 written, count: 54
# Block #0 written, count: 55
# Block #1 written, count: 56
# Block #2 written, count: 57
# Block #3 written, count: 58
# Block #4 written, count: 59
# Block #0 written, count: 60
# Block #1 written, count: 1
# Block #2 written, count: 2
# Block #3 written, count: 3
# Block #4 written, count: 4
# Block #0 written, count: 5
# Block #1 written, count: 6
# Block #2 written, count: 7
# Block #3 written, count: 8
# Block #4 written, count: 9
# Block #0 written, count: 10
# Block #1 written, count: 11
# Block #2 written, count: 12
# Block #3 written, count: 13
# Block #4 written, count: 14
# Block #0 written, count: 15
# Block #1 written, count: 16
# Block #2 written, count: 17
# Block #3 written, count: 18
# Block #4 written, count: 19
# Block #0 written, count: 20
# Block #1 written, count: 21
# Block #2 written, count: 22
# Block #3 written, count: 23
# Block #4 written, count: 24
# Block #0 written, count: 25
# Block #1 written, count: 26
# Block #2 written, count: 27
# Block #3 written, count: 28
# Block #4 written, count: 29
# Block #0 written, count: 30
# Block #1 written, count: 31
# Block #2 written, count: 32
# Block #3 written, count: 33
# Block #4 written, count: 34
# Block #0 written, count: 35
# Block #1 written, count: 36
# Block #2 written, count: 37
# Block #3 written, count: 38
# Block #4 written, count: 39
# Block #0 written, count: 40
# Block #1 written, count: 41
# Block #2 written, count: 42
# Block #3 written, count: 43
# Block #4 written, count: 44
# Block #0 written, count: 45
# Block #1 written, count: 46
# Block #2 written, count: 47
# Block #3 written, count: 48
# Block #4 written, count: 49
# Block #0 written, count: 50
# Block #1 written, count: 51
# Block #2 written, count: 52
# Block #3 written, count: 53
# Block #4 written, count: 54
# Block #0 written, count: 55
# Block #1 written, count: 56
# Block #2 written, count: 57
# Block #3 written, count: 58
# Block #4 written, count: 59
# Block #0 written, count: 60
# Block #1 written, count: 1
# Block #2 written, count: 2
# Block #3 written, count: 3
# Block #4 written, count: 4
# Block #0 written, count: 5
# Block #1 written, count: 6
# Block #2 written, count: 7
# Block #3 written, count: 8
# Block #4 written, count: 9
# Block #0 written, count: 10
# Block #1 written, count: 11
# Block #2 written, count: 12
# Block #3 written, count: 13
# Block #4 written, count: 14
# Block #0 written, count: 15
# Block #1 written, count: 16
# Block #2 written, count: 17
# Block #3 written, count: 18
# Block #4 written, count: 19
# Block #0 written, count: 20
# Block #1 written, count: 21
# Block #2 written, count: 22
# Block #3 written, count: 23
# Block #4 written, count: 24
# Block #0 written, count: 25
# Block #1 written, count: 26
# Block #2 written, count: 27
# Block #3 written, count: 28
# Block #4 written, count: 29
# Block #0 written, count: 30
# Block #1 written, count: 31
# Block #2 written, count: 32
# Block #3 written, count: 33
# Block #4 written, count: 34
# Block #0 written, count: 35
# Block #1 written, count: 36
# Block #2 written, count: 37
# Block #3 written, count: 38
# Block #4 written, count: 39
# Block #0 written, count: 40
# Block #1 written, count: 41
# Block #2 written, count: 42
# Block #3 written, count: 43
# Block #4 written, count: 44
# Block #0 written, count: 45
# Block #1 written, count: 46
# Block #2 written, count: 47
# Block #3 written, count: 48
# Block #4 written, count: 49
# Block #0 written, count: 50
# Block #1 written, count: 51
# Block #2 written, count: 52
# Block #3 written, count: 53
# Block #4 written, count: 54
# Block #0 written, count: 55
# Block #1 written, count: 56
# Block #2 written, count: 57
# Block #3 written, count: 58
# Block #4 written, count: 59
# Block #0 written, count: 60
# Block #1 written, count: 1
# Block #2 written, count: 2
# Block #3 written, count: 3
# Block #4 written, count: 4
# Block #0 written, count: 5
# Block #1 written, count: 6
# Block #2 written, count: 7
# Block #3 written, count: 8
# Block #4 written, count: 9
# Block #0 written, count: 10
# Block #1 written, count: 11
# Block #2 written, count: 12
# Block #3 written, count: 13
# Block #4 written, count: 14
# Block #0 written, count: 15
# Block #1 written, count: 16
# Block #2 written, count: 17
# Block #3 written, count: 18
# Block #4 written, count: 19
# Block #0 written, count: 20
# Block #1 written, count: 21
# Block #2 written, count: 22
# Block #3 written, count: 23
# Block #4 written, count: 24
# Block #0 written, count: 25
# Block #1 written, count: 26
# Block #2 written, count: 27
# Block #3 written, count: 28
# Block #4 written, count: 29
# Block #0 written, count: 30
# Block #1 written, count: 31
# Block #2 written, count: 32
# Block #3 written, count: 33
# Block #4 written, count: 34
# Block #0 written, count: 35
# Block #1 written, count: 36
# Block #2 written, count: 37
# Block #3 written, count: 38
# Block #4 written, count: 39
# Block #0 written, count: 40
# Block #1 written, count: 41
# Block #2 written, count: 42
# Block #3 written, count: 43
# Block #4 written, count: 44
# Block #0 written, count: 45
# Block #1 written, count: 46
# Block #2 written, count: 47
# Block #3 written, count: 48
# Block #4 written, count: 49
# Block #0 written, count: 50
# Block #1 written, count: 51
# Block #2 written, count: 52
# Block #3 written, count: 53
# Block #4 written, count: 54
# Block #0 written, count: 55
# Block #1 written, count: 56
# Block #2 written, count: 57
# Block #3 written, count: 58
# Block #4 written, count: 59
# Block #0 written, count: 60
# Block #1 written, count: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-fd80a25aa3f5> in <module>
#       5 while True:
#       6     while last_blk == blk_ptr.contents.value:
# ----> 7         time.sleep(0.01)
#       8
#       9     data = voltage[BLK_SIZE*last_blk:BLK_SIZE*(last_blk+1)]
#
# KeyboardInterrupt:

# %%
voltage.shape, cast(blk_ptr, c_void_p).value, blk_ptr.contents

# %%
last_blk = blk_ptr.contents.value
for n in range(20):
    while blk_ptr.contents.value == last_blk:
        time.sleep(0.01)

    last_blk = blk_ptr.contents.value
    print(last_blk)

# %%
voltage[:16]

# %%
24 * 1024
